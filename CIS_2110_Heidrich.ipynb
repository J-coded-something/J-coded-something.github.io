# %% [markdown]
# <a href="https://colab.research.google.com/github/J-coded-something/J-coded-something.github.io/blob/main/CIS_2110_Heidrich.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Business P1.14
print("Your friends birthdays")
print(" ") #gives blank space

name1 = "Tommy"
name2 = "John"
name3 = "Briana"

birthday1 = "01/22/1995"
birthday2 = "04/12/1997"
birthday3 = "07/01/2000"

print(name1, birthday1)
print(name2, birthday2)
print(name3, birthday3)

print(" ") #gives blank space
print(" ") #gives blank space
# Business P1.15
print("Sales Tax Rates")
print(" ") #gives blank space
print("California: 7.25%")
print("Arkansas: 6.5%")
print("Florida: 6%")
print("Idaho: 6%")
print("Hawaii: 4%")
# Out:
# Your friends birthdays
#
# Tommy 01/22/1995
# John 04/12/1997
# Briana 07/01/2000
#
#
# Sales Tax Rates
#
# California: 7.25%
# Arkansas: 6.5%
# Florida: 6%
# Idaho: 6%
# Hawaii: 4%
